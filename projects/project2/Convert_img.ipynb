# %%
from PIL import Image
import os

# %%
# !pwd
# Out:
# /Users/zhangyuyao/Desktop/Exchange EPFL/ML_course/projects/project2

# %%
root = "/Users/zhangyuyao/Desktop/Exchange EPFL/ML_proj/ID0311_221017_UL_test_nano/"

# %%
SlicesY_path = os.path.join(root, 'SlicesY/')
os.listdir(SlicesY_path)
# Out:
# ['slice00596.tif',
#  'slice00582.tif',
#  'slice00233.tif',
#  'slice00555.tif',
#  'slice00541.tif',
#  'slice00227.tif',
#  'slice01139.tif',
#  'slice01111.tif',
#  'slice00569.tif',
#  'slice01105.tif',
#  'slice00794.tif',
#  'slice00958.tif',
#  'slice00780.tif',
#  'slice00970.tif',
#  'slice00964.tif',
#  'slice00757.tif',
#  'slice00031.tif',
#  'slice00025.tif',
#  'slice00743.tif',
#  'slice00019.tif',
#  'slice00838.tif',
#  'slice01298.tif',
#  'slice00186.tif',
#  'slice00192.tif',
#  'slice00804.tif',
#  'slice00810.tif',
#  'slice00623.tif',
#  'slice00145.tif',
#  'slice00151.tif',
#  'slice00637.tif',
#  'slice00179.tif',
#  'slice01267.tif',
#  'slice01273.tif',
#  'slice00384.tif',
#  'slice00390.tif',
#  'slice01059.tif',
#  'slice00347.tif',
#  'slice00421.tif',
#  'slice00435.tif',
#  'slice00353.tif',
#  'slice01065.tif',
#  'slice00409.tif',
#  'slice01071.tif',
#  'slice00408.tif',
#  'slice01070.tif',
#  'slice01064.tif',
#  'slice00434.tif',
# ...

# %%
for tif in os.listdir(SlicesY_path):
    png = tif[:-3] + 'png'
    im = Image.open(SlicesY_path + tif)
    out = im.convert('RGB')
    out.save(png, "PNG", quality=90)

# %%
os.mkdir('converted_Y')

# %%
# !ls
# Out:
# Convert_img.ipynb        slice00432.png           slice00867.png
# converted_Y              slice00433.png           slice00868.png
# project2_description.pdf slice00434.png           slice00869.png
# slice00000.png           slice00435.png           slice00870.png
# slice00001.png           slice00436.png           slice00871.png
# slice00002.png           slice00437.png           slice00872.png
# slice00003.png           slice00438.png           slice00873.png
# slice00004.png           slice00439.png           slice00874.png
# slice00005.png           slice00440.png           slice00875.png
# slice00006.png           slice00441.png           slice00876.png
# slice00007.png           slice00442.png           slice00877.png
# slice00008.png           slice00443.png           slice00878.png
# slice00009.png           slice00444.png           slice00879.png
# slice00010.png           slice00445.png           slice00880.png
# ...

# %%
for png in os.curdir:
    if png[:-3] == 'png':
        os.rename(png, os.path.join('./converted_y', png))
